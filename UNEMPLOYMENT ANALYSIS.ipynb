# %% [markdown]
# # G Samuel Raj

# %% [markdown]
# Data Science Intern @ Oasis infobyte-OIBSIP

# %% [markdown]
# ***

# %% [markdown]
# # TASK # 3 CAR PRICE PREDICTION

# %% [markdown]
# __Problem Statement__
# - Unemployment is measured by the unemployment rate which is the number of people
# who are unemployed as a percentage of the total labour force.
# - We have seen a sharp
# increase in the unemployment rate during Covid-19, so analyzing the unemployment rate
# can be a good data science project.

# %% [markdown]
# Dataset -https://www.kaggle.com/datasets/saurabh00007/iriscsv

# %% [markdown]
# ***

# %% [markdown]
# __importing all required libraries__

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv("C:\\Users\\samue\\OneDrive\\Desktop\\data_sets\\Unemployment in India.csv")
df2 = pd.read_csv("C:\\Users\\samue\\OneDrive\\Desktop\\data_sets\\Unemployment_Rate_upto_11_2020.csv")

# %%
df1.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
df1.isnull().sum()
df1
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
df2.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %%
df1.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
df2.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# ...

# %%
df1.tail()
# Out:
#     Region  Date  Frequency   Estimated Unemployment Rate (%)  \
# 763    NaN   NaN        NaN                               NaN
# 764    NaN   NaN        NaN                               NaN
# 765    NaN   NaN        NaN                               NaN
# 766    NaN   NaN        NaN                               NaN
# 767    NaN   NaN        NaN                               NaN
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Area
# 763                  NaN                                       NaN  NaN
# 764                  NaN                                       NaN  NaN
# 765                  NaN                                       NaN  NaN
# 766                  NaN                                       NaN  NaN
# 767                  NaN                                       NaN  NaN

# %%
df2.tail()
# Out:
#           Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 262  West Bengal   30-06-2020          M                              7.29
# 263  West Bengal   31-07-2020          M                              6.83
# 264  West Bengal   31-08-2020          M                             14.87
# 265  West Bengal   30-09-2020          M                              9.35
# 266  West Bengal   31-10-2020          M                              9.98
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 262             30726310                                     40.39     East
# 263             35372506                                     46.17     East
# 264             33298644                                     47.48     East
# 265             35707239                                     47.73     East
# 266             33962549                                     45.63     East
#
#      longitude  latitude
# 262    22.9868    87.855
# ...

# %%
df1.info
# Out:
# <bound method DataFrame.info of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
# Strip leading/trailing spaces from the column names
df2.columns = df2.columns.str.strip()

# Plotting the bar chart (full dataset)
plt.figure(figsize=(20,10))
plt.bar(df2['Region'], df2['Estimated Unemployment Rate (%)'])

# Set xtick labels correctly with rotation
plt.xticks(rotation=90, ha='right')

# Adding labels and title
plt.xlabel('Region')
plt.ylabel('Estimated Unemployment Rate (%)')
plt.title('Estimated Unemployment Rate by Region')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Strip leading/trailing spaces from the column names
df1.columns = df1.columns.str.strip()

# Check for NaN values in 'Region' and 'Estimated Unemployment Rate (%)'
print(df1[['Region', 'Estimated Unemployment Rate (%)']].isna().sum())

# Drop rows with NaN values in 'Region' or 'Estimated Unemployment Rate (%)'
df1 = df1.dropna(subset=['Region', 'Estimated Unemployment Rate (%)'])

# Ensure 'Region' column is of string type
df1['Region'] = df1['Region'].astype(str)

# Plotting the bar chart (full dataset)
plt.figure(figsize=(20,10))
plt.bar(df1['Region'], df1['Estimated Unemployment Rate (%)'])

# Set xtick labels correctly with rotation
plt.xticks(rotation=90, ha='right')

# Adding labels and title
plt.xlabel('Region')
plt.ylabel('Estimated Unemployment Rate (%)')
plt.title('Estimated Unemployment Rate by time')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# Region                             28
# Estimated Unemployment Rate (%)    28
# dtype: int64

# %%
print(df2.columns)
# Out:
# Index(['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate (%)',
#        'Estimated Employed', 'Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %%
df2.columns = df2.columns.str.strip()

# Selecting only the numeric columns for correlation matrix
numeric_cols = df2.select_dtypes(include=[float, int])

# Calculating the correlation matrix
corr_matrix = numeric_cols.corr()

# Plotting the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='viridis')

# Adding title
plt.title('Correlation Matrix')

# Show the plot
plt.show()

# %%
sns.pairplot(df2, hue='Region',palette='Dark2')

# %%
# Plotting the histogram using 'Estimated Employed' and 'Region'
sns.histplot(x='Estimated Employed', hue='Region', data=df2)

# Show the plot
plt.show()

# %%
# Plotting the histogram using 'Estimated Employed' and 'Region'
sns.histplot(x='Estimated Employed', hue='Region', data=df1)

# Show the plot
plt.show()

# %%
# Remove leading space from 'Date' column name
df2.rename(columns={' Date': 'Date'}, inplace=True)

# Create the line plot
fig = px.line(df2, x='Date', y='Estimated Unemployment Rate (%)', 
              title='Unemployment Rate Over Time', 
              labels={'Estimated Unemployment Rate (%)': 'Unemployment Rate'},
              template='plotly_dark')

# Add the shape for the COVID-19 event period
covid_event = {'start_date': '2020-03-01', 'end_date': '2021-06-30', 'event': 'Peak of Pandemic'}
fig.add_shape(type='rect', 
              x0=pd.to_datetime(covid_event['start_date']), 
              x1=pd.to_datetime(covid_event['end_date']), 
              y0=0, y1=1, 
              fillcolor='red', opacity=0.3, layer='below', 
              line=dict(color='red', width=2))

# Update layout
fig.update_layout(xaxis_title='Date', yaxis_title='Unemployment Rate', legend_title='Region')
fig.update_xaxes(type='category')

# Show the plot
fig.show()

# %%
fig = px.bar(df2, x='Region', y='Estimated Unemployment Rate (%)', color='Region',
             animation_frame='Date', title='Unemployment Rate Over Time',
             labels={'Estimated Unemployment Rate (%)': 'Unemployment Rate (%)'},
             template='plotly', color_discrete_sequence=px.colors.sequential.Viridis,
             category_orders={'Region': ['Region1', 'Region2', 'Region3']})

fig.update_layout(xaxis={'categoryorder': 'total descending'},
                  xaxis_title='Region', yaxis_title='Unemployment Rate (%)',
                  barmode='stack', showlegend=False)

fig.add_annotation(text='Impact of Unemployment Over Time',
                   xref='paper', yref='paper', x=0.5, y=1.05,
                   showarrow=False, font=dict(size=16, color='black'))

fig.show()

# %%
fig = px.bar(df1, x='Region', y='Estimated Unemployment Rate (%)', color='Region',
             animation_frame='Date', title='Unemployment Rate in india',
             labels={'Estimated Unemployment Rate (%)': 'Unemployment Rate (%)'},
             template='plotly', color_discrete_sequence=px.colors.sequential.Viridis,
             category_orders={'Region': ['Region1', 'Region2', 'Region3']})

fig.update_layout(xaxis={'categoryorder': 'total descending'},
                  xaxis_title='Region', yaxis_title='Unemployment Rate (%)',
                  barmode='stack', showlegend=False)

fig.add_annotation(text='Impact of Unemployment in India',
                   xref='paper', yref='paper', x=0.5, y=1.05,
                   showarrow=False, font=dict(size=16, color='black'))

fig.show()

# %%
df2['Date'] = pd.to_datetime(df2['Date'],infer_datetime_format=True)
df2['Date']
# Out:
# 0     2020-01-31
# 1     2020-02-29
# 2     2020-03-31
# 3     2020-04-30
# 4     2020-05-31
#          ...
# 262   2020-06-30
# 263   2020-07-31
# 264   2020-08-31
# 265   2020-09-30
# 266   2020-10-31
# Name: Date, Length: 267, dtype: datetime64[ns]
